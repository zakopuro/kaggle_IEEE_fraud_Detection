# %%
import pandas as pd
import lightgbm as lgb
import pickle

# %%
filename = '/Users/zakopuro/Code/python_code/kaggle/IEEE_Fraud_Detection/model/069_lgb.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
lgb.plot_importance(loaded_model,max_num_features=30)
