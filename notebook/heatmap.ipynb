# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_pickle('/Users/zakopuro/Code/python_code/kaggle/IEEE_Fraud_Detection/src/make_data/data/030_train.pkl')
df_test = pd.read_pickle('/Users/zakopuro/Code/python_code/kaggle/IEEE_Fraud_Detection/src/make_data/data/030_test.pkl')

# %%
need_list =['C1', 'V3', 'V27', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36',
       'V37', 'V38', 'V254', 'V255', 'V256', 'V257', 'V258', 'V259', 'V260',
       'V261', 'V262', 'V263', 'V264', 'V265', 'V266', 'V268', 'V269', 'V270',
       'V271', 'V272', 'V273', 'V298', 'V300', 'V301', 'V302', 'V303', 'V304',
       'V305', 'V306', 'V307', 'V308', 'V309', 'V311', 'V312', 'V313', 'V314',
       'V315', 'V316', 'V317', 'V318', 'V319', 'V320', 'V321', 'V322', 'V324',
       'V325', 'V327', 'V328', 'V329', 'V330', 'V331', 'V334', 'V335', 'V336',
       'V337', 'V338', 'V339']

# %%
V10_list = ['V3', 'V27', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36','V37', 'V38']

# %%
V200_list = ['V254', 'V255', 'V256', 'V257', 'V258', 'V259', 'V260',
       'V261', 'V262', 'V263', 'V264', 'V265', 'V266', 'V268', 'V269', 'V270',
       'V271', 'V272', 'V273', 'V298', 'V300', 'V301', 'V302', 'V303', 'V304',
       'V305', 'V306', 'V307', 'V308', 'V309', 'V311', 'V312', 'V313', 'V314',
       'V315', 'V316', 'V317', 'V318', 'V319', 'V320', 'V321', 'V322', 'V324',
       'V325', 'V327', 'V328', 'V329', 'V330', 'V331', 'V334', 'V335', 'V336',
       'V337', 'V338', 'V339']

# %%
df_corr = df_train[V200_list]

# %%
fig, axes = plt.subplots(figsize=(20, 20))
sns.heatmap(df_corr.corr(), ax=axes)

# %%
# for i in range(len(need_list)):
#     df_coor = df_train[need_list[]]
#     sns.heatmap(df_corr.corr(), vmax=1, vmin=-1, center=0)
